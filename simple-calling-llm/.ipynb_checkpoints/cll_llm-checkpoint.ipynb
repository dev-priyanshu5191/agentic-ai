# %%
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI

load_dotenv()
# Out:
# True

# %%
llm = ChatGoogleGenerativeAI(model = "gemma-4-31b-it")
response = llm.invoke("How many model in Agentic AI")
print(response.text)
# Out:
# It is important to first clarify a common misconception: **Agentic AI is not a specific "model," but rather a "design pattern" or an "architecture."**
#
# You cannot count the number of models in Agentic AI because **almost any powerful Large Language Model (LLM) can be used as the "brain" of an agent.**
#
# To understand this better, think of it this way: The **LLM is the engine**, and **Agentic AI is the car** built around that engine.
#
# Here is the detailed breakdown of how models fit into Agentic AI:
#
# ---
#
# ### 1. The "Brain" (The Base Models)
# An agent requires a model capable of reasoning, planning, and following complex instructions. While many models can be used, the most common ones include:
# *   **Proprietary Models:** GPT-4o (OpenAI), Claude 3.5 Sonnet (Anthropic), Gemini 1.5 Pro (Google).
# *   **Open-Source Models:** Llama 3 (Meta), Mistral/Mixtral, Qwen.
#
# ### 2. Single-Agent vs. Multi-Agent Systems
# ...

# %%
response = llm.invoke([
    ["system", "You have to answer in one line"],
    ["humans", "Define LLM ?"]
])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 response = llm.invoke([
#       2     ["system", "You have to answer in one line"],
#       3     ["humans", "Define LLM ?"]
#       4 ])
#
# File D:\tutorial-agentic-ai\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:2672, in ChatGoogleGenerativeAI.invoke(self, input, config, code_execution, stop, **kwargs)
#    2669         msg = "Tools are already defined.code_execution tool can't be defined"
#    2670         raise ValueError(msg)
# -> 2672 return super().invoke(input, config, stop=stop, **kwargs)
#
# File D:\tutorial-agentic-ai\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:475, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     460 @override
#     461 def invoke(
#     462     self,
#    (...)    467     **kwargs: Any,
# ...

# %%
response = llm.invoke([
    ["system", "You have to answer in one line"],
    ["humans", "Define LLM ?"]
])

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 response = llm.invoke([
#       2     ["system", "You have to answer in one line"],
#       3     ["humans", "Define LLM ?"]
#       4 ])
#
# File D:\tutorial-agentic-ai\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:2672, in ChatGoogleGenerativeAI.invoke(self, input, config, code_execution, stop, **kwargs)
#    2669         msg = "Tools are already defined.code_execution tool can't be defined"
#    2670         raise ValueError(msg)
# -> 2672 return super().invoke(input, config, stop=stop, **kwargs)
#
# File D:\tutorial-agentic-ai\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:475, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     460 @override
#     461 def invoke(
#     462     self,
#    (...)    467     **kwargs: Any,
# ...

# %%
response = llm.invoke([
    ["system", "You have to answer in one line"],
    ["human", "Define LLM ?"]
])

print(response.text)
# Out:
# A Large Language Model (LLM) is an AI system trained on vast amounts of text data to understand, generate, and manipulate human-like language.

# %%
llm = ChatGoogleGnenerativeAI(model = "gemini-2.5-flash", temperature=1)
response = llm.invoke(prompt)
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 llm = ChatGoogleGnenerativeAI(model = "gemini-2.5-flash", temperature=1)
#       2 response = llm.invoke(prompt)
#       3 print(response.text)
#
# NameError: name 'ChatGoogleGnenerativeAI' is not defined

# %%
prompt = "Suggest me some name for my Sattu brand"
llm = ChatGoogleGenerativeAI(model = "gemini-2.5-flash", temperature=1)
response = llm.invoke(prompt)
print(response.text)
# Out:
# That's exciting! Sattu is a fantastic product. Here are some name suggestions for your Sattu brand, categorized by the vibe they evoke:
#
# ---
#
# ### **Traditional & Authentic**
#
# These names lean into the heritage and natural goodness of Sattu.
#
# 1.  **Parampara Sattu** (Parampara means tradition)
# 2.  **Dadi's Sattu** (Grandma's Sattu - evokes warmth & authenticity)
# 3.  **Bhoomi Sattu** (Bhoomi means earth/land - natural, earthy)
# 4.  **Heritage Sattu**
# 5.  **Gramin Sattu** (Gramin means rural/village - authentic, wholesome)
# 6.  **Ancient Grains Sattu**
# 7.  **Desi Sattu**
# 8.  **Roots Sattu**
# 9.  **The Sattu Mill** (Suggests traditional processing)
# 10. **Prakriti Sattu** (Prakriti means nature)
#
# ---
#
# ### **Health & Wellness Focused**
#
# These names highlight the nutritional benefits and healthy aspect of Sattu.
#
# 1.  **SattuVigor** (Vigor means energy, strength)
# 2.  **NutriSattu**
# 3.  **Vital Sattu**
# 4.  **Wholsum Sattu** (Wholesome)
# ...

# %%
response = llm.invoke([
    ["system", "Only in one word"],
    ["human", prompt]
])
print(response.text)
# Out:
# Prana
